# %%
from models.TransBTS.TransBTS_downsample8x_skipconnection import TransBTS

# %%
# _, model = TransBTS(dataset='brats', _conv_repr=True, _pe_type="learned")
_, model = TransBTS(_conv_repr=True, _pe_type="learned")

# %%
model.eval()
# Out:
# BTS(
#   (linear_encoding): Linear(in_features=128, out_features=512, bias=True)
#   (position_encoding): LearnedPositionalEncoding()
#   (pe_dropout): Dropout(p=0.1, inplace=False)
#   (transformer): TransformerModel(
#     (net): IntermediateSequential(
#       (0): Residual(
#         (fn): PreNormDrop(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fn): SelfAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=False)
#             (attn_drop): Dropout(p=0.1, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): Residual(
#         (fn): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=4096, bias=True)
#               (1): GELU(approximate='none')
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=4096, out_features=512, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (2): Residual(
#         (fn): PreNormDrop(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fn): SelfAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=False)
#             (attn_drop): Dropout(p=0.1, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): Residual(
#         (fn): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=4096, bias=True)
#               (1): GELU(approximate='none')
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=4096, out_features=512, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (4): Residual(
#         (fn): PreNormDrop(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fn): SelfAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=False)
#             (attn_drop): Dropout(p=0.1, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): Residual(
#         (fn): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=4096, bias=True)
#               (1): GELU(approximate='none')
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=4096, out_features=512, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (6): Residual(
#         (fn): PreNormDrop(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fn): SelfAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=False)
#             (attn_drop): Dropout(p=0.1, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): Residual(
#         (fn): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=4096, bias=True)
#               (1): GELU(approximate='none')
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=4096, out_features=512, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#     )
#   )
#   (pre_head_ln): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   (conv_x): Conv3d(128, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#   (Unet): Unet(
#     (InitConv): InitConv(
#       (conv): Conv3d(1, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#     (EnBlock1): EnBlock(
#       (bn1): GroupNorm(8, 16, eps=1e-05, affine=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (bn2): GroupNorm(8, 16, eps=1e-05, affine=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#     (EnDown1): EnDown(
#       (conv): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#     )
#     (EnBlock2_1): EnBlock(
#       (bn1): GroupNorm(8, 32, eps=1e-05, affine=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (bn2): GroupNorm(8, 32, eps=1e-05, affine=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#     (EnBlock2_2): EnBlock(
#       (bn1): GroupNorm(8, 32, eps=1e-05, affine=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (bn2): GroupNorm(8, 32, eps=1e-05, affine=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#     (EnDown2): EnDown(
#       (conv): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#     )
#     (EnBlock3_1): EnBlock(
#       (bn1): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (bn2): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#     (EnBlock3_2): EnBlock(
#       (bn1): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (bn2): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#     (EnDown3): EnDown(
#       (conv): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#     )
#     (EnBlock4_1): EnBlock(
#       (bn1): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (bn2): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#     (EnBlock4_2): EnBlock(
#       (bn1): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (bn2): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#     (EnBlock4_3): EnBlock(
#       (bn1): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (bn2): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#     (EnBlock4_4): EnBlock(
#       (bn1): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (bn2): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#   )
#   (bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (pool): AdaptiveAvgPool1d(output_size=1)
#   (fc1): Linear(in_features=512, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
import torch
input_tensor = torch.randn(1, 1, 128, 128, 128)  # B = batch size
# input_tensor = torch.randn(1, 1, 91, 109, 91)  # B = batch size

# %%
with torch.no_grad():
    output = model(input_tensor)
# Out:
# log1
# Inside encoder
# Inside encoder 1
# Inside encoder 2
# Inside encoder 3
# Inside encoder 4
# Inside encoder 5
# Inside encoder 6
# Inside encoder 8
# Inside encoder 9
# Inside encoder 10
# Inside encoder 11
# Inside encoder 12
# x1_1:-  torch.Size([1, 16, 128, 128, 128])
# x2_1:-  torch.Size([1, 32, 64, 64, 64])
# x3_1:-  torch.Size([1, 64, 32, 32, 32])
# encoder_output:-  torch.Size([1, 4096, 512])
# intmd_encoder_outputs:-  {'0': tensor([[[ 0.3513, -0.1204,  0.2981,  ..., -0.4775, -0.0310,  0.1571],
#          [ 0.3372, -0.0221,  0.4220,  ..., -0.5003,  0.2014,  0.3329],
#          [ 0.4001, -0.1691,  0.3203,  ..., -0.4963,  0.2759,  0.1937],
#          ...,
#          [ 0.2236, -0.3287, -0.0900,  ..., -0.4056, -0.0694,  0.3711],
#          [ 0.1000, -0.2000,  0.0334,  ..., -0.4041,  0.0537,  0.2400],
#          [ 0.0696, -0.0869,  0.0588,  ..., -0.2167,  0.0806,  0.3588]]]), '1': tensor([[[ 1.4125e-01, -5.0498e-02,  6.8342e-01,  ..., -4.3027e-01,
#           -4.5949e-01,  1.0716e-02],
#          [ 1.6133e-01,  4.2298e-02,  7.3463e-01,  ..., -4.8752e-01,
#           -2.1382e-01,  1.0875e-01],
#          [ 3.7137e-01, -1.1563e-01,  6.0841e-01,  ..., -4.7401e-01,
#           -1.8577e-02,  8.4734e-02],
#          ...,
#          [ 1.6181e-04, -2.0091e-01, -9.7742e-02,  ..., -4.5711e-01,
#           -1.1929e-01,  3.1400e-01],
#          [-1.9414e-01, -8.8598e-02,  2.7843e-02,  ..., -3.8571e-01,
#            5.1683e-02,  1.3906e-01],
#          [-1.8590e-01, -1.3261e-04,  2.3398e-01,  ..., -2.6467e-01,
#           -1.6059e-01,  2.8997e-01]]]), '2': tensor([[[ 0.1790,  0.1429,  0.2952,  ..., -0.7906, -0.2786,  0.2079],
#          [ 0.2020,  0.2365,  0.3475,  ..., -0.8507, -0.0355,  0.3092],
#          [ 0.4102,  0.0768,  0.2233,  ..., -0.8331,  0.1623,  0.2842],
#          ...,
#          [ 0.0347, -0.0098, -0.4830,  ..., -0.8206,  0.0616,  0.5101],
#          [-0.1558,  0.1033, -0.3576,  ..., -0.7503,  0.2329,  0.3364],
#          [-0.1483,  0.1952, -0.1487,  ..., -0.6293,  0.0176,  0.4868]]]), '3': tensor([[[-0.0168,  0.4824,  0.1943,  ..., -1.0645, -0.1299,  0.1508],
#          [ 0.0511,  0.4963,  0.3099,  ..., -1.0911,  0.1955,  0.3000],
#          [ 0.2142,  0.3990,  0.3211,  ..., -1.1648,  0.2779,  0.2387],
#          ...,
#          [ 0.1044,  0.2893, -0.5399,  ..., -0.9350,  0.0546,  0.4644],
#          [-0.1642,  0.3690, -0.4390,  ..., -0.7894,  0.1860,  0.2854],
#          [-0.1897,  0.5318, -0.2388,  ..., -0.8303,  0.1156,  0.4861]]]), '4': tensor([[[-0.1536,  0.2493,  0.0879,  ..., -1.2747, -0.2358,  0.1702],
#          [-0.0876,  0.2635,  0.2037,  ..., -1.3001,  0.0899,  0.3201],
#          [ 0.0746,  0.1664,  0.2160,  ..., -1.3752,  0.1719,  0.2581],
#          ...,
#          [-0.0310,  0.0551, -0.6474,  ..., -1.1452, -0.0537,  0.4788],
#          [-0.3010,  0.1343, -0.5455,  ..., -1.0017,  0.0794,  0.3052],
#          [-0.3283,  0.2973, -0.3435,  ..., -1.0415,  0.0104,  0.5058]]]), '5': tensor([[[-0.6558,  0.1752, -0.0878,  ..., -1.0229, -0.3971,  0.1934],
#          [-0.5313,  0.2526,  0.0637,  ..., -1.1162, -0.0822,  0.4072],
#          [-0.3524,  0.1903,  0.0679,  ..., -1.1295,  0.0133,  0.2770],
#          ...,
#          [-0.6009,  0.0765, -0.9602,  ..., -0.9846, -0.1584,  0.5717],
#          [-0.8574,  0.0856, -0.8388,  ..., -0.8629, -0.0743,  0.3133],
#          [-0.9703,  0.3127, -0.6339,  ..., -0.7992, -0.1328,  0.5790]]]), '6': tensor([[[-0.5832, -0.1483,  0.0994,  ..., -0.8985, -0.9286,  0.7804],
#          [-0.4583, -0.0714,  0.2508,  ..., -0.9926, -0.6145,  0.9945],
#          [-0.2794, -0.1336,  0.2548,  ..., -1.0054, -0.5199,  0.8657],
#          ...,
#          [-0.5293, -0.2461, -0.7731,  ..., -0.8620, -0.6892,  1.1618],
#          [-0.7845, -0.2369, -0.6512,  ..., -0.7403, -0.6042,  0.9017],
#          [-0.8977, -0.0100, -0.4474,  ..., -0.6753, -0.6637,  1.1678]]]), '7': tensor([[[-0.6204, -0.1406,  0.1787,  ..., -0.8678, -0.7761,  0.6510],
#          [-0.4580, -0.0566,  0.3727,  ..., -0.9269, -0.4581,  0.8273],
#          [-0.3595, -0.1193,  0.3465,  ..., -0.8576, -0.3522,  0.6997],
#          ...,
#          [-0.5133, -0.2511, -0.6242,  ..., -0.6847, -0.5277,  1.0254],
#          [-0.8006, -0.2588, -0.5166,  ..., -0.5897, -0.4871,  0.7867],
#          [-0.8932, -0.0311, -0.3670,  ..., -0.5820, -0.6002,  1.0817]]])}

# %%
output.shape
# Out:
# torch.Size([1, 1])

# %%
import torch
import torch.nn as nn

class EncoderToFloat(nn.Module):
    def __init__(self):
        super().__init__()
        self.pool = nn.AdaptiveAvgPool1d(1)   # Pool over sequence length
        self.fc1 = nn.Linear(512, 128)
        self.fc2 = nn.Linear(128, 1)
        self.sigmoid = nn.Sigmoid()           # Output between 0 and 1

    def forward(self, x):
        # x shape: [1, 4096, 512] → transpose to [1, 512, 4096]
        x = x.transpose(1, 2)
        x = self.pool(x)                      # → [1, 512, 1]
        x = x.squeeze(-1)                     # → [1, 512]
        x = self.fc1(x)
        x = torch.relu(x)
        x = self.fc2(x)                       # → [1, 1]
        x = self.sigmoid(x)                   # [0, 1]
        return x * 100                        # scale to [0, 100]

# Example usage
model = EncoderToFloat()
encoder_output = torch.randn(1, 4096, 512)
output = model(encoder_output)
print(output.item())  # A float in [0, 100]
