# %%
import os
import pandas as pd
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
BrainMRIFilesPath = r"C:\Users\Rishabh\Downloads\train"
CSVPath = r"C:\Users\Rishabh\Downloads\triamese_data.xlsx"
Files = os.listdir(BrainMRIFilesPath)

# %%
df = pd.read_excel(CSVPath, engine='openpyxl')

# %%
df.head(10)
# Out:
#                           Image_Path  IXI_ID        AGE  SEX_ID Modality  \
# 0    IXI-T2/IXI097-HH-1619-T2.nii.gz      97  35.022587       2       T1
# 1  IXI-T2/IXI026-Guys-0696-T2.nii.gz      26  34.477755       2       T1
# 2  IXI-T2/IXI308-Guys-0884-T2.nii.gz     308  41.204654       1       T1
# 3  IXI-T2/IXI592-Guys-1085-T2.nii.gz     592  48.079398       1       T1
# 4  IXI-T2/IXI107-Guys-0761-T2.nii.gz     107  31.895962       2       T1
# 5    IXI-T2/IXI277-HH-1770-T2.nii.gz     277  61.336071       2       T1
# 6  IXI-T2/IXI198-Guys-0803-T2.nii.gz     198  45.256674       1       T1
# 7  IXI-T2/IXI020-Guys-0700-T2.nii.gz      20  39.466119       1       T1
# 8    IXI-T2/IXI180-HH-1605-T2.nii.gz     180  42.151951       2       T1
# 9  IXI-T2/IXI662-Guys-1120-T2.nii.gz     662  41.741273       1       T1
#
#                                       new_image_path
# 0  /home/omen/Documents/Megha/normalised/IXI097-H...
# 1  /home/omen/Documents/Megha/normalised/IXI026-G...
# 2  /home/omen/Documents/Megha/normalised/IXI308-G...
# 3  /home/omen/Documents/Megha/normalised/IXI592-G...
# 4  /home/omen/Documents/Megha/normalised/IXI107-G...
# 5  /home/omen/Documents/Megha/normalised/IXI277-H...
# 6  /home/omen/Documents/Megha/normalised/IXI198-G...
# 7  /home/omen/Documents/Megha/normalised/IXI020-G...
# 8  /home/omen/Documents/Megha/normalised/IXI180-H...
# 9  /home/omen/Documents/Megha/normalised/IXI662-G...

# %%
for file in Files:
    img = nib.load(os.path.join(BrainMRIFilesPath, file))
    data = img.get_fdata()
    data = data[:,50,:]
    print(data.shape)
    print("min:- ", np.min(data), '  max:- ', np.max(data),' unique values:- ', len(np.unique(data)) )
    mean_of_array = data.mean()
    std_of_array = data.std()
    print('mean:- ', mean_of_array,' std:- ', std_of_array)
    print("--------"*10)

    # values = data.flatten()

    # plt.figure(figsize=(8, 5))
    # sns.kdeplot(values, bw_adjust=0.5, fill=True)
    # plt.title("Dense Value Distribution (KDE) of 3D Array") 
    # plt.xlabel("Value")
    # plt.ylabel("Density")
    # plt.grid(True)
    # plt.show()
# Out:
# (91, 91)
# min:-  0.0   max:-  506.6102065511686  unique values:-  3732
# mean:-  159.05010067218515  std:-  190.32213602913436
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  642.8102338559117  unique values:-  3245
# mean:-  70.58707952988283  std:-  102.43418445245997
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  1466.478148122132  unique values:-  3536
# mean:-  166.14051930969083  std:-  237.18119290529376
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  1176.6564805103671  unique values:-  3333
# mean:-  150.83203743121823  std:-  213.1780250980971
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  581.0155411439223  unique values:-  3514
# mean:-  135.36365303570705  std:-  173.52714329573178
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  622.6261468743495  unique values:-  3555
# mean:-  94.30426274832567  std:-  131.77699067870276
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  566.7143753310289  unique values:-  3416
# mean:-  85.655760579955  std:-  128.43981989062738
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  3859.839061463171  unique values:-  3448
# mean:-  1100.6198695437827  std:-  1389.196093084529
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  2663.9632659725476  unique values:-  3452
# mean:-  391.64814139568773  std:-  506.83469363865663
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  1048.8093469239768  unique values:-  3514
# mean:-  145.39174985313187  std:-  212.17513264828176
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  468.87296672742906  unique values:-  1954
# mean:-  66.22155246297366  std:-  131.12465673135884
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  916.9011783988956  unique values:-  3120
# mean:-  108.26622149409589  std:-  165.48871123282865
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  736.9917351207699  unique values:-  2603
# mean:-  144.9015284740094  std:-  232.0837675614706
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  2541.2684116375895  unique values:-  3597
# mean:-  367.46725209233796  std:-  471.5975883036392
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  996.9226685507393  unique values:-  3391
# mean:-  135.90855046297787  std:-  196.81118476268443
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  1047.1679623336786  unique values:-  3547
# mean:-  124.32669585253598  std:-  176.43276220959257
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  695.5665175627121  unique values:-  3544
# mean:-  188.08128419729366  std:-  239.07923061426223
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  493.8109942579571  unique values:-  3316
# mean:-  115.72146917873205  std:-  155.67385775406672
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  610.1739623768335  unique values:-  3413
# mean:-  83.03555449727725  std:-  120.96196634276161
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  815.1475715031262  unique values:-  3754
# mean:-  223.497301123478  std:-  267.50897362735026
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  1014.4968683956902  unique values:-  3475
# mean:-  126.05978999564218  std:-  183.07765128399828
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  699.3399451345928  unique values:-  2030
# mean:-  101.5146075149538  std:-  194.71493530719536
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  972.7350487574354  unique values:-  3496
# mean:-  117.36789946210344  std:-  168.28109588961573
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  731.9668918116951  unique values:-  3118
# mean:-  167.42526540420542  std:-  237.72322023235375
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  910.3586324314605  unique values:-  3425
# mean:-  106.56104686352413  std:-  151.45496530536712
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  456.71719891110484  unique values:-  3669
# mean:-  134.95892140852737  std:-  165.7447985405366
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  3718.6177293190267  unique values:-  3705
# mean:-  1168.5119370304353  std:-  1383.6906830402322
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  55.28503668060906  unique values:-  3054
# mean:-  12.26385333251173  std:-  17.656733980878794
# --------------------------------------------------------------------------------
# (91, 91)
# min:-  0.0   max:-  602.2683918551642  unique values:-  3372
# mean:-  85.31699653765457  std:-  125.57888591366851
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[55], line 3
#       1 for file in Files:
#       2     img = nib.load(os.path.join(BrainMRIFilesPath, file))
# ----> 3     data = img.get_fdata()
#       4     data = data[:,50,:]
#       5     print(data.shape)
#
# File ~\anaconda3\envs\TransBTS\Lib\site-packages\nibabel\dataobj_images.py:374, in DataobjImage.get_fdata(self, caching, dtype)
#     370         return self._fdata_cache
#     371 # Always return requested data type
#     372 # For array proxies, will attempt to confine data array to dtype
#     373 # during scaling
# --> 374 data = np.asanyarray(self._dataobj, dtype=dtype)
#     375 if caching == 'fill':
#     376     self._fdata_cache = data
#
# File ~\anaconda3\envs\TransBTS\Lib\site-packages\nibabel\arrayproxy.py:454, in ArrayProxy.__array__(self, dtype)
#     433 def __array__(self, dtype=None):
#     434     """Read data from file and apply scaling, casting to ``dtype``
#     435
#     436     If ``dtype`` is unspecified, the dtype of the returned array is the
#    (...)    452         Scaled image data with type `dtype`.
#     453     """
# --> 454     arr = self._get_scaled(dtype=dtype, slicer=())
#     455     if dtype is not None:
#     456         arr = arr.astype(dtype, copy=False)
#
# File ~\anaconda3\envs\TransBTS\Lib\site-packages\nibabel\arrayproxy.py:421, in ArrayProxy._get_scaled(self, dtype, slicer)
#     419     scl_inter = scl_inter.astype(use_dtype)
#     420 # Read array and upcast as necessary for big slopes, intercepts
# --> 421 scaled = apply_read_scaling(self._get_unscaled(slicer=slicer), scl_slope, scl_inter)
#     422 if dtype is not None:
#     423     scaled = scaled.astype(np.promote_types(scaled.dtype, dtype), copy=False)
#
# File ~\anaconda3\envs\TransBTS\Lib\site-packages\nibabel\arrayproxy.py:391, in ArrayProxy._get_unscaled(self, slicer)
#     387 if canonical_slicers(slicer, self._shape, False) == canonical_slicers(
#     388     (), self._shape, False
#     389 ):
#     390     with self._get_fileobj() as fileobj, self._lock:
# --> 391         return array_from_file(
#     392             self._shape,
#     393             self._dtype,
#     394             fileobj,
#     395             offset=self._offset,
#     396             order=self.order,
#     397             mmap=self._mmap,
#     398         )
#     399 with self._get_fileobj() as fileobj:
#     400     return fileslice(
#     401         fileobj,
#     402         slicer,
#    (...)    407         lock=self._lock,
#     408     )
#
# File ~\anaconda3\envs\TransBTS\Lib\site-packages\nibabel\volumeutils.py:467, in array_from_file(shape, in_dtype, infile, offset, order, mmap)
#     465 if hasattr(infile, 'readinto'):
#     466     data_bytes = bytearray(n_bytes)
# --> 467     n_read = infile.readinto(data_bytes)
#     468     needs_copy = False
#     469 else:
#
# File ~\anaconda3\envs\TransBTS\Lib\gzip.py:301, in GzipFile.read(self, size)
#     299     import errno
#     300     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 301 return self._buffer.read(size)
#
# File ~\anaconda3\envs\TransBTS\Lib\_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File ~\anaconda3\envs\TransBTS\Lib\gzip.py:518, in _GzipReader.read(self, size)
#     516         break
#     517     if buf == b"":
# --> 518         raise EOFError("Compressed file ended before the "
#     519                        "end-of-stream marker was reached")
#     521 self._add_read_data( uncompress )
#     522 self._pos += len(uncompress)
#
# EOFError: Compressed file ended before the end-of-stream marker was reached

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Example 3D array (replace with your data)
array_3d = np.random.randn(64, 64, 64)  # or your volume data

# Flatten to 1D
values = array_3d.flatten()

# Plot KDE
plt.figure(figsize=(8, 5))
sns.kdeplot(values, bw_adjust=0.5, fill=True)
plt.title("Dense Value Distribution (KDE) of 3D Array")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\rishabh\anaconda3\envs\transbts\lib\site-packages (from seaborn) (2.1.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\rishabh\anaconda3\envs\transbts\lib\site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\rishabh\anaconda3\envs\transbts\lib\site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rishabh\anaconda3\envs\transbts\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\rishabh\anaconda3\envs\transbts\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rishabh\anaconda3\envs\transbts\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rishabh\anaconda3\envs\transbts\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\rishabh\anaconda3\envs\transbts\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\rishabh\anaconda3\envs\transbts\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rishabh\anaconda3\envs\transbts\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rishabh\anaconda3\envs\transbts\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rishabh\anaconda3\envs\transbts\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rishabh\anaconda3\envs\transbts\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\rishabh\anaconda3\envs\transbts\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
