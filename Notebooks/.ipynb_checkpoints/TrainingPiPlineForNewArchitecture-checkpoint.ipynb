# %%
from models.TransBTS.TransBTS_downsample8x_skipconnection import TransBTS
from torch.utils.data import Dataset, DataLoader
import numpy as np
import matplotlib.pyplot as plt
import os
import nibabel as nib
import pandas as pd
from monai.transforms import LoadImage, Compose, Spacing, Resize, EnsureChannelFirst, ScaleIntensity
import numpy as np
import torch

# %%
class TransBTS_model_dataset_enoder_only(Dataset):
    def __init__(self, BrainMRIFilesPath, CSVPath, transform=None):        
        self.BrainMRIFilesPath = BrainMRIFilesPath
        self.CSVPath = CSVPath
        self.transform = transform
        self.df = pd.read_excel(self.CSVPath , engine='openpyxl')
        
        self.Files = os.listdir(self.BrainMRIFilesPath)

        self.ID_To_Filename = {}
        self.IDs = []
        self.Lables = {}
        for file in self.Files:
            strc = file.split('-')
            self.ID_To_Filename[int(strc[0][-3:])] = file
            self.IDs.append(int(strc[0][-3:]))
            self.Lables[int(strc[0][-3:])] = np.random.randint(0, 2, size=(4096, 512), dtype=np.int32)

    def __len__(self):
        return len(self.IDs)

    def __getitem__(self, index):
        ID = self.IDs[index]
        filename = self.ID_To_Filename[ID]
        file_path = os.path.join(self.BrainMRIFilesPath ,filename)
        if self.transform is not None:
            image = transforms(file_path)              # returns torch.Tensor
            array = image.numpy()[0]                    
        
        age = self.df[self.df['IXI_ID'] == ID]['AGE'].values[0]
        Label = self.Lables[ID]
        return array, Label

# %%
transforms = Compose([
    LoadImage(image_only=True),
    EnsureChannelFirst(),                   # shape: (1, H, W, D)
    ScaleIntensity(),                       # optional: normalize to 0-1
    Spacing(pixdim=(1.0, 1.0, 1.0), mode="bilinear"),  # resample to 1mm spacing
    Resize(spatial_size=(128, 128, 128), mode='trilinear')  # resize to 128³
])

# %%
BrainMRIFilesPath = r"C:\Users\Rishabh\Documents\PreprocessedData1mm"
CSVPath = os.path.join(r'C:\Users\Rishabh\Documents\TransBTS', 'IXI.xlsx')
ds = TransBTS_model_dataset_enoder_only(BrainMRIFilesPath, CSVPath , transforms)
loader = DataLoader(ds, batch_size=1, shuffle=True, num_workers=0)

# %%
_, model = TransBTS(_conv_repr=True, _pe_type="learned")
model.eval()
# Out:
# BTS(
#   (linear_encoding): Linear(in_features=128, out_features=512, bias=True)
#   (position_encoding): LearnedPositionalEncoding()
#   (pe_dropout): Dropout(p=0.1, inplace=False)
#   (transformer): TransformerModel(
#     (net): IntermediateSequential(
#       (0): Residual(
#         (fn): PreNormDrop(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fn): SelfAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=False)
#             (attn_drop): Dropout(p=0.1, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): Residual(
#         (fn): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=4096, bias=True)
#               (1): GELU(approximate='none')
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=4096, out_features=512, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (2): Residual(
#         (fn): PreNormDrop(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fn): SelfAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=False)
#             (attn_drop): Dropout(p=0.1, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): Residual(
#         (fn): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=4096, bias=True)
#               (1): GELU(approximate='none')
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=4096, out_features=512, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (4): Residual(
#         (fn): PreNormDrop(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fn): SelfAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=False)
#             (attn_drop): Dropout(p=0.1, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): Residual(
#         (fn): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=4096, bias=True)
#               (1): GELU(approximate='none')
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=4096, out_features=512, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (6): Residual(
#         (fn): PreNormDrop(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fn): SelfAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=False)
#             (attn_drop): Dropout(p=0.1, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): Residual(
#         (fn): PreNorm(
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=512, out_features=4096, bias=True)
#               (1): GELU(approximate='none')
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=4096, out_features=512, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#     )
#   )
#   (pre_head_ln): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   (conv_x): Conv3d(128, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#   (Unet): Unet(
#     (InitConv): InitConv(
#       (conv): Conv3d(1, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#     (EnBlock1): EnBlock(
#       (bn1): GroupNorm(8, 16, eps=1e-05, affine=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (bn2): GroupNorm(8, 16, eps=1e-05, affine=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#     (EnDown1): EnDown(
#       (conv): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#     )
#     (EnBlock2_1): EnBlock(
#       (bn1): GroupNorm(8, 32, eps=1e-05, affine=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (bn2): GroupNorm(8, 32, eps=1e-05, affine=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#     (EnBlock2_2): EnBlock(
#       (bn1): GroupNorm(8, 32, eps=1e-05, affine=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (bn2): GroupNorm(8, 32, eps=1e-05, affine=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#     (EnDown2): EnDown(
#       (conv): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#     )
#     (EnBlock3_1): EnBlock(
#       (bn1): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (bn2): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#     (EnBlock3_2): EnBlock(
#       (bn1): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (bn2): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#     (EnDown3): EnDown(
#       (conv): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#     )
#     (EnBlock4_1): EnBlock(
#       (bn1): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (bn2): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#     (EnBlock4_2): EnBlock(
#       (bn1): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (bn2): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#     (EnBlock4_3): EnBlock(
#       (bn1): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (bn2): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#     (EnBlock4_4): EnBlock(
#       (bn1): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (bn2): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     )
#   )
#   (bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
# )

# %%
import torch.nn as nn

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
criterion = nn.BCELoss()

# %%
from tqdm import tqdm
num_epochs = 2
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    with tqdm(loader, desc=f"Epoch {epoch+1}/{num_epochs}") as t:
        for batch in t:
            Imagevol = batch[0]
            Imagevol = Imagevol.unsqueeze(1)
            Label = batch[1]
            encoder_output, intmd_encoder_outputs = model(Imagevol)  
            encoder_output = torch.sigmoid(encoder_output)
            loss = criterion(encoder_output, Label.float())
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            t.set_postfix(loss=loss.item())

            
            print(loss)
# Out:
# Epoch 1/2:   6%|███▌                                                        | 1/17 [00:18<05:03, 18.96s/it, loss=0.802]
# tensor(0.8022, grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch 1/2:  12%|███████                                                     | 2/17 [00:37<04:39, 18.65s/it, loss=0.792]
# tensor(0.7919, grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch 1/2:  18%|██████████▌                                                 | 3/17 [00:55<04:20, 18.61s/it, loss=0.782]
# tensor(0.7819, grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch 1/2:  18%|██████████▌                                                 | 3/17 [01:02<04:53, 20.94s/it, loss=0.782]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 11
#       9 Imagevol = Imagevol.unsqueeze(1)
#      10 Label = batch[1]
# ---> 11 encoder_output, intmd_encoder_outputs = model(Imagevol)
#      12 encoder_output = torch.sigmoid(encoder_output)
#      13 loss = criterion(encoder_output, Label.float())
#
# File ~\anaconda3\envs\TransBTS\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\TransBTS\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\Documents\TransBTS\models\TransBTS\TransBTS_downsample8x_skipconnection.py:177, in TransformerBTS.forward(self, x, auxillary_output_layers)
#     174 def forward(self, x, auxillary_output_layers=[1, 2, 3, 4]):
#     175     # print("log1")
# --> 177     x1_1, x2_1, x3_1, encoder_output, intmd_encoder_outputs = self.encode(x)
#     178     # print('x1_1:- ',x1_1.shape)
#     179     # print('x2_1:- ',x2_1.shape)
#     180     # print('x3_1:- ',x3_1.shape)
#    (...)    184
#     185     # Custom_Decoder_Output = self.custom_decoder(encoder_output)
#     187     return encoder_output, intmd_encoder_outputs
#
# File ~\Documents\TransBTS\models\TransBTS\TransBTS_downsample8x_skipconnection.py:150, in TransformerBTS.encode(self, x)
#     145 x = self.pe_dropout(x)
#     147 # print("Inside encoder 10")
#     148
#     149 # apply transformer
# --> 150 x, intmd_x = self.transformer(x)
#     152 # print("Inside encoder 11")
#     153 x = self.pre_head_ln(x)
#
# File ~\anaconda3\envs\TransBTS\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\TransBTS\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\Documents\TransBTS\models\TransBTS\Transformer.py:119, in TransformerModel.forward(self, x)
#     118 def forward(self, x):
# --> 119     return self.net(x)
#
# File ~\anaconda3\envs\TransBTS\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\TransBTS\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\Documents\TransBTS\models\TransBTS\IntmdSequential.py:16, in IntermediateSequential.forward(self, input)
#      14 output = input
#      15 for name, module in self.named_children():
# ---> 16     output = intermediate_outputs[name] = module(output)
#      18 return output, intermediate_outputs
#
# File ~\anaconda3\envs\TransBTS\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\TransBTS\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\Documents\TransBTS\models\TransBTS\Transformer.py:48, in Residual.forward(self, x)
#      47 def forward(self, x):
# ---> 48     return self.fn(x) + x
#
# File ~\anaconda3\envs\TransBTS\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\TransBTS\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\Documents\TransBTS\models\TransBTS\Transformer.py:69, in PreNormDrop.forward(self, x)
#      68 def forward(self, x):
# ---> 69     return self.dropout(self.fn(self.norm(x)))
#
# File ~\anaconda3\envs\TransBTS\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\TransBTS\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\Documents\TransBTS\models\TransBTS\Transformer.py:33, in SelfAttention.forward(self, x)
#      26 q, k, v = (
#      27     qkv[0],
#      28     qkv[1],
#      29     qkv[2],
#      30 )  # make torchscript happy (cannot use tensor as tuple)
#      32 attn = (q @ k.transpose(-2, -1)) * self.scale
# ---> 33 attn = attn.softmax(dim=-1)
#      34 attn = self.attn_drop(attn)
#      36 x = (attn @ v).transpose(1, 2).reshape(B, N, C)
#
# KeyboardInterrupt:
